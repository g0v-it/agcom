# %%
import pandas as pd
from matplotlib import pyplot as plt

pd.__version__
# Out:
# '1.4.3'

# %%
url_gen_mar_2018 = "https://www.agcom.it/documents/10179/22930991/Dati+monitoraggio+17-05-2021+1621347034830/d9b71509-d7ff-4833-b18a-232d291f7110?version=1.0"
df_gen_mar_2018 = pd.read_xml(url_gen_mar_2018, encoding = 'UTF-8')

url_apr_giu_2018 = "file:///C:/Users/utente/Downloads/Dati%20monitoraggio%2017-05-2021%201621346337800.xml"
df_apr_giu_2018 = pd.read_xml(url_apr_giu_2018, encoding = 'UTF-8')

url_lug_set_2018 = "file:///C:/Users/utente/Downloads/Dati%20monitoraggio%2017-05-2021%201621347034830%20(3).xml"
df_lug_set_2018 = pd.read_xml(url_lug_set_2018, encoding = 'UTF-8')

url_ott_dic_2018 = "file:///C:/Users/utente/Downloads/Dati%20monitoraggio%2017-05-2021%201621347998455.xml"
df_ott_dic_2018 = pd.read_xml(url_ott_dic_2018, encoding = 'UTF-8')

# %%
df_gen_mar_2018 = df_gen_mar_2018.iloc[2:,:]
df_apr_giu_2018 = df_apr_giu_2018.iloc[2:,:]
df_lug_set_2018 = df_lug_set_2018.iloc[2:,:]
df_ott_dic_2018 = df_ott_dic_2018.iloc[2:,:]


del df_gen_mar_2018['TESTO']
del df_apr_giu_2018['TESTO']
del df_lug_set_2018['TESTO']
del df_ott_dic_2018['TESTO']

# %%
url_gen_mar_2019 = "file:///C:/Users/utente/Downloads/Dati%20monitoraggio%2017-05-2021%201621349232000%20(1).xml"
df_gen_mar_2019 = pd.read_xml(url_gen_mar_2019, encoding = 'UTF-8')

url_apr_giu_2019 = "file:///C:/Users/utente/Downloads/Dati%20monitoraggio%2017-05-2021%201621351682573.xml"
df_apr_giu_2019 = pd.read_xml(url_apr_giu_2019, encoding = 'UTF-8')

url_lug_set_2019 = "file:///C:/Users/utente/Downloads/Dati%20monitoraggio%2017-05-2021%201621351846336.xml"
df_lug_set_2019 = pd.read_xml(url_lug_set_2019, encoding = 'UTF-8')

url_ott_dic_2019 = "file:///C:/Users/utente/Downloads/Dati%20monitoraggio%2017-05-2021%201621352032185.xml"
df_ott_dic_2019 = pd.read_xml(url_ott_dic_2019, encoding = 'UTF-8')

# %%
df_gen_mar_2019 = df_gen_mar_2019.iloc[2:,:]
df_apr_giu_2019 = df_apr_giu_2019.iloc[2:,:]
df_lug_set_2019 = df_lug_set_2019.iloc[2:,:]
df_ott_dic_2019 = df_ott_dic_2019.iloc[2:,:]


del df_gen_mar_2019['TESTO']
del df_apr_giu_2019['TESTO']
del df_lug_set_2019['TESTO']
del df_ott_dic_2019['TESTO']

# %%
url_gen_mar_2020 = "file:///C:/Users/utente/Downloads/Dati%20monitoraggio%2017-05-2021%201621352637182.xml"
df_gen_mar_2020 = pd.read_xml(url_gen_mar_2020, encoding = 'UTF-8')

url_apr_giu_2020 = "file:///C:/Users/utente/Downloads/Dati%20monitoraggio%2017-05-2021%201621352798394.xml"
df_apr_giu_2020 = pd.read_xml(url_apr_giu_2020, encoding = 'UTF-8')

url_lug_set_2020 = "file:///C:/Users/utente/Downloads/Dati%20monitoraggio%2017-05-2021%201621353107073.xml"
df_lug_set_2020 = pd.read_xml(url_lug_set_2020, encoding = 'UTF-8')

url_ott_dic_2020 = "file:///C:/Users/utente/Downloads/Dati%20monitoraggio%2017-05-2021%201621353236367.xml"
df_ott_dic_2020 = pd.read_xml(url_ott_dic_2020, encoding = 'UTF-8')

# %%
df_gen_mar_2020 = df_gen_mar_2020.iloc[2:,:]
df_apr_giu_2020 = df_apr_giu_2020.iloc[2:,:]
df_lug_set_2020 = df_lug_set_2020.iloc[2:,:]
df_ott_dic_2020 = df_ott_dic_2020.iloc[2:,:]


del df_gen_mar_2020['TESTO']
del df_apr_giu_2020['TESTO']
del df_lug_set_2020['TESTO']
del df_ott_dic_2020['TESTO']

# %%
url_gen_2021 = "file:///C:/Users/utente/Downloads/Dati%20monitoraggio%2024-04-2021.xml"
df_gen_2021 = pd.read_xml(url_gen_2021, encoding = 'UTF-8')

url_feb_2021 = "file:///C:/Users/utente/Downloads/Dati%20monitoraggio%2024-04-2021%201619431026146.xml"
df_feb_2021 = pd.read_xml(url_feb_2021, encoding = 'UTF-8')

url_mar_2021 = "file:///C:/Users/utente/Downloads/Dati%20monitoraggio%2024-04-2021%201619431424018.xml"
df_mar_2021 = pd.read_xml(url_mar_2021, encoding = 'UTF-8')

url_apr_2021 = "file:///C:/Users/utente/Downloads/Dati%20monitoraggio%2014-10-2021.xml"
df_apr_2021 = pd.read_xml(url_apr_2021, encoding = 'UTF-8')

url_mag_2021 = "file:///C:/Users/utente/Downloads/Dati%20monitoraggio%2014-10-2021%201634288071192.xml"
df_mag_2021 = pd.read_xml(url_mag_2021, encoding = 'UTF-8')

url_giu_2021 = "file:///C:/Users/utente/Downloads/Dati%20monitoraggio%2014-10-2021%201634288207850.xml"
df_giu_2021 = pd.read_xml(url_giu_2021, encoding = 'UTF-8')

url_lug_2021 = "file:///C:/Users/utente/Downloads/Dati%20monitoraggio%2025-01-2022.xml"
df_lug_2021 = pd.read_xml(url_lug_2021, encoding = 'UTF-8')

url_ago_2021 = "file:///C:/Users/utente/Downloads/Dati%20monitoraggio%2025-01-2022.xml"
df_ago_2021 = pd.read_xml(url_ago_2021, encoding = 'UTF-8')

url_set_2021 = "file:///C:/Users/utente/Downloads/Dati%20monitoraggio%2025-01-2022%201643201573705.xml"
df_set_2021 = pd.read_xml(url_set_2021, encoding = 'UTF-8')

url_ott_2021 = "file:///C:/Users/utente/Downloads/Dati%20monitoraggio%2022-02-2022%20(1).xml"
df_ott_2021 = pd.read_xml(url_ott_2021, encoding = 'UTF-8')

url_nov_2021 = "file:///C:/Users/utente/Downloads/Dati%20monitoraggio%2022-02-2022%201645789648181.xml"
df_nov_2021 = pd.read_xml(url_nov_2021, encoding = 'UTF-8')

url_dic_2021 = "file:///C:/Users/utente/Downloads/Dati%20monitoraggio%2022-02-2022%201645791266888.xml"
df_dic_2021 = pd.read_xml(url_dic_2021, encoding = 'UTF-8')

# %%
df_gen_2021 = df_gen_2021.iloc[2:,:]
df_feb_2021 = df_feb_2021.iloc[2:,:]
df_mar_2021 = df_mar_2021.iloc[2:,:]
df_apr_2021 = df_apr_2021.iloc[2:,:]
df_mag_2021 = df_mag_2021.iloc[2:,:]
df_giu_2021 = df_giu_2021.iloc[2:,:]
df_lug_2021 = df_lug_2021.iloc[2:,:]
df_ago_2021 = df_ago_2021.iloc[2:,:]
df_set_2021 = df_set_2021.iloc[2:,:]
df_ott_2021 = df_ott_2021.iloc[2:,:]
df_nov_2021 = df_nov_2021.iloc[2:,:]
df_dic_2021 = df_dic_2021.iloc[2:,:]


del df_gen_2021['TESTO']
del df_feb_2021['TESTO']
del df_mar_2021['TESTO']
del df_apr_2021['TESTO']
del df_mag_2021['TESTO']
del df_giu_2021['TESTO']
del df_lug_2021['TESTO']
del df_ago_2021['TESTO']
del df_set_2021['TESTO']
del df_ott_2021['TESTO']
del df_nov_2021['TESTO']
del df_dic_2021['TESTO']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'TESTO'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df = [df_gen_mar_2018,
      df_apr_giu_2018,
      df_lug_set_2018,
      df_ott_dic_2018]

df_2018 = pd.concat(df)
display(df_2018)
# Out:
#          CANALE               PROGRAMMA                 DATA  \
# 2      CANALE 5       ANTICIPAZIONI TG5  02.08.2018 00:00:00
# 3      CANALE 5       ANTICIPAZIONI TG5  03.08.2018 00:00:00
# 4      CANALE 5       ANTICIPAZIONI TG5  07.07.2018 00:00:00
# 5      CANALE 5       ANTICIPAZIONI TG5  27.07.2018 00:00:00
# 6      CANALE 5       ANTICIPAZIONI TG5  28.08.2018 00:00:00
# ...         ...                     ...                  ...
# 47022       TV8  SKY TG24 - MATTINA (I)  05.11.2018 00:00:00
# 47023       TV8  SKY TG24 - MATTINA (I)  14.11.2018 00:00:00
# 47024       TV8  SKY TG24 - MATTINA (I)  27.11.2018 00:00:00
# 47025       TV8  SKY TG24 - MATTINA (I)  04.12.2018 00:00:00
# 47026       TV8  SKY TG24 - MATTINA (I)  05.12.2018 00:00:00
#
#                   COGNOME                 NOME      MICRO_CATEGORIA  \
# 2               Lega Nord  Soggetto collettivo            Lega Nord
# 3               Lega Nord  Soggetto collettivo            Lega Nord
# ...

# %%
df = [df_gen_mar_2019,
      df_apr_giu_2019,
      df_lug_set_2019,
      df_ott_dic_2019]

df_2019 = pd.concat(df)
display(df_2019)
# Out:
#          CANALE              PROGRAMMA                 DATA  \
# 2      CANALE 5      ANTICIPAZIONI TG5  05.01.2019 00:00:00
# 3      CANALE 5      ANTICIPAZIONI TG5  08.01.2019 00:00:00
# 4      CANALE 5      ANTICIPAZIONI TG5  10.01.2019 00:00:00
# 5      CANALE 5      ANTICIPAZIONI TG5  07.02.2019 00:00:00
# 6      CANALE 5      ANTICIPAZIONI TG5  09.02.2019 00:00:00
# ...         ...                    ...                  ...
# 59064       TV8  SKY TG24 - BUONGIORNO  04.12.2019 00:00:00
# 59065       TV8  SKY TG24 - BUONGIORNO  10.12.2019 00:00:00
# 59066       TV8  SKY TG24 - BUONGIORNO  11.12.2019 00:00:00
# 59067       TV8  SKY TG24 - BUONGIORNO  17.12.2019 00:00:00
# 59068       TV8  SKY TG24 - BUONGIORNO  20.12.2019 00:00:00
#
#                   COGNOME                 NOME      MICRO_CATEGORIA  \
# 2      Movimento 5 Stelle  Soggetto collettivo   Movimento 5 Stelle
# 3                   Renzi               Matteo  Partito Democratico
# ...

# %%
df = [df_gen_mar_2020,
      df_apr_giu_2020,
      df_lug_set_2020,
      df_ott_dic_2020]

df_2020 = pd.concat(df)
display(df_2020)
# Out:
#          CANALE                                PROGRAMMA                 DATA  \
# 2      CANALE 5  AMICI DI MARIA DE FILIPPI - STAGIONE 20  28.02.2020 00:00:00
# 3      CANALE 5                        ANTICIPAZIONI TG5  13.01.2020 00:00:00
# 4      CANALE 5                        ANTICIPAZIONI TG5  15.01.2020 00:00:00
# 5      CANALE 5                        ANTICIPAZIONI TG5  10.02.2020 00:00:00
# 6      CANALE 5                        ANTICIPAZIONI TG5  11.02.2020 00:00:00
# ...         ...                                      ...                  ...
# 48474       TV8                      VENTI20... QUASI 21  23.12.2020 00:00:00
# 48475       TV8            VENTI20: I VENT'ANNI DEL 2000  22.12.2020 00:00:00
# 48476       TV8            VENTI20: I VENT'ANNI DEL 2000  22.12.2020 00:00:00
# 48477       TV8            VENTI20: I VENT'ANNI DEL 2000  22.12.2020 00:00:00
# 48478       TV8            VENTI20: I VENT'ANNI DEL 2000  22.12.2020 00:00:00
#
# ...

# %%
df = [df_gen_2021, df_feb_2021, df_mar_2021,
     df_apr_2021, df_mag_2021, df_giu_2021,
     df_lug_2021, df_ago_2021, df_set_2021,
     df_ott_2021, df_nov_2021, df_dic_2021]

df_2021 = pd.concat(df)
display(df_2021)
# Out:
#          CANALE             PROGRAMMA              DATA              COGNOME  \
# 4      CANALE 5     ANTICIPAZIONI TG5  21.01.2021 00:00              Salvini
# 5      CANALE 5     ANTICIPAZIONI TG5  26.01.2021 00:00  Partito Democratico
# 6      CANALE 5     ANTICIPAZIONI TG5  30.01.2021 00:00   Movimento 5 Stelle
# 7      CANALE 5  LIVE NON � LA D'URSO  17.01.2021 00:00                Zampa
# 8      CANALE 5        MATTINO CINQUE  20.01.2021 00:00              Salvini
# ...         ...                   ...               ...                  ...
# 13088       TV8              SKY TG24        31.12.2021                Letta
# 13089       TV8              SKY TG24        31.12.2021   Movimento 5 Stelle
# 13090       TV8              SKY TG24        31.12.2021             Nardella
# 13091       TV8              SKY TG24        31.12.2021  Partito Democratico
# 13092       TV8              SKY TG24        31.12.2021           Provenzano
#
# ...

# %%
df_lug_set_2018.MICRO_CATEGORIA.value_counts()
# Out:
# Partito Democratico                          12292
# PDL - Forza Italia                           10210
# Lega Nord                                     5186
# Movimento 5 Stelle                            5138
# Altro                                         3674
# Liberi e Uguali                               1818
# Fratelli d'Italia                             1724
# Noi con l'Italia                               197
# + Europa �Centro Democratico                   184
# Civica popolare- AP-Psi-Area Civica            152
# Per le Autonomie - Minoranze linguistiche      133
# L'Altra Europa con Tsipras                      28
# Casa Pound                                       2
# Name: MICRO_CATEGORIA, dtype: int64

# %%
df_lug_set_2018.COGNOME.value_counts()
# Out:
# Toti                   1939
# Movimento 5 Stelle     1926
# Lega Nord              1790
# Martina                1668
# Partito Democratico    1629
#                        ...
# Toci                      1
# Sperandio                 1
# De Blasio                 1
# Anzalone                  1
# Codognotto                1
# Name: COGNOME, Length: 1180, dtype: int64

# %%
df_lug_set_2018.COGNOME.value_counts()
# Out:
# Toti                   1939
# Movimento 5 Stelle     1926
# Lega Nord              1790
# Martina                1668
# Partito Democratico    1629
#                        ...
# Toci                      1
# Sperandio                 1
# De Blasio                 1
# Anzalone                  1
# Codognotto                1
# Name: COGNOME, Length: 1180, dtype: int64
